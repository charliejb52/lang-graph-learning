# %% [markdown]
# # **Prompts in LangGraph**

# %% [markdown]
# ## **Boilerplate**

# %%
from dotenv import load_dotenv
import os

load_dotenv()

if os.environ["OPENAI_API_KEY"]:
    print("OpenAI api key set")
else:
    raise ValueError("OpenAI api key is not set")
# Out:
# OpenAI api key set

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# ### **Step 1: Create a Prompt**

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "you are a helpful assistant that helps to create and curate posts for social media"),
        ("human", "I want to create a post about {topic}")
    ]
)
# Out:
# ChatPromptTemplate(input_variables=[], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are a helpful assistant that helps to create and curate posts for social media'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='I want to create a post about my new position as the CEO of The Chair Company'), additional_kwargs={})])
