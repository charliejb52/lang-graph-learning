# %% [markdown]
# # **Prompts in LangGraph**

# %% [markdown]
# ## **Boilerplate**

# %%
from dotenv import load_dotenv
import os

load_dotenv()

if os.environ["OPENAI_API_KEY"]:
    print("OpenAI api key set")
else:
    raise ValueError("OpenAI api key is not set")
# Out:
# OpenAI api key set

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# ### **Step 1: Create a Prompt**

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "you are a helpful assistant that helps to create and curate posts for social media"),
        ("human", "I want to create a post about {topic}")
    ]
)

prompt_filled = my_prompt.invoke({"topic": "my new position as the CEO of The Chair Company"})

# %%
llm.invoke(prompt_filled)
# Out:
# AIMessage(content='Congratulations on your new position as CEO of The Chair Company! Here’s a draft for your social media post:\n\n---\n\n🌟 Exciting News! 🌟 \n\nI am thrilled to share that I have officially stepped into the role of CEO at The Chair Company! 🎉✨ \n\nI couldn’t be more excited to lead such an innovative team dedicated to crafting quality furniture that transforms spaces and elevates experiences. 🌈🪑 \n\nAs we move forward, I look forward to fostering creativity, collaboration, and sustainability while driving our mission to design chairs that not only fit beautifully in homes and offices but also resonate with our customers on a deeper level. \n\nA heartfelt thank you to everyone who has supported me on this journey—your encouragement means the world! Here’s to new beginnings and exciting challenges ahead. Let’s build something extraordinary together! \n\n#CEO #Leadership #TheChairCompany #NewBeginnings #FurnitureDesign #Innovation #Teamwork\n\n---\n\nFeel free to custom
# ...

# %% [markdown]
# ### **Step 2: Chain With Prompts**

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "my new position as the CEO of The Chair Company"})
# Out:
# AIMessage(content="Congratulations on your new position! Here's a suggested post you can use to announce this exciting news:\n\n---\n\n🎉 Exciting News! 🎉\n\nI am thrilled to share that I have officially stepped into the role of CEO at The Chair Company! 🪑✨\n\nI am incredibly grateful for this opportunity and look forward to leading such a passionate and talented team. Together, we will innovate and elevate our brand, creating beautiful and functional furniture that brings comfort and style to homes around the world.\n\nStay tuned for exciting updates and initiatives as we embark on this journey to redefine the seating experience. Thank you for your continued support and encouragement! \n\n#NewBeginnings #CEO #TheChairCompany #Leadership #FurnitureDesign\n\n---\n\nFeel free to customize it further to match your voice and style!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 43, 'total_tokens': 201, 'completion_token
# ...
